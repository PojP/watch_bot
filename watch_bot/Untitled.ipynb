# %%
#from src.db_controller import db
import pyrogram
from config_reader import config
import asyncio
import re
from pyrogram import Client

api_id = int(config.api_id.get_secret_value())
api_hash = config.api_hash.get_secret_value()
content_chat_id=int(config.chat_id.get_secret_value())
target_chat_id=-1001902274622
target_chat_id2=-1001566319632


from src.db_controller import db

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def capital(s:str) -> str:
    return s.capitalize()

# %%
print(1)
async with Client("my_account", api_id, api_hash) as app:
    #print(await app.get_chat(target_chat_id2))
    msgs_cnt=await app.get_chat_history_count(target_chat_id2)
    #print(msgs_cnt)
    counter=0
    titles=[]
    alph="йцукенгшщзхъфывапролджэячсмитьбюqwertyuiopasdfghjklzxcvbnm"
    alph+=alph.upper()+"0123456789"
    
    async for message in app.get_chat_history(target_chat_id2):
        if message.caption is not None and message.video is not None and message.video.duration>600:
            #print(message.caption)
            s=message.caption.split('\n')
            s=( " ".join(list(map(capital, (s[0].split('.')[1].split(' (')[0]).split() )))   +"\n"+s[1])
            #print(s)
            
            br=(s,message.video.file_id)
            titles.append(br)
            
            """if s[0] not in alph:
                s=s[1:]
            s=s.split("#")[0]
            s= ' '.join(s.split())
            s=remove_emoji(s)
            bad_array=["https://t.me/gairithi/83"]
            if s not in titles and not s.split(" «")[0].isdigit():
                if not any(ext in s for ext in bad_array):
                    s=s.split('/')[0]
                    s=
                    s=s.replace("Hd 1080p","").replace("Sd",'').replace("Hd",'').replace('720p','').replace('_'," ")
                    br=(s,message.video.file_id)
                    titles.append(br)
                    print(br)
                    counter+=1
            
    print(counter)"""
    print()
    print()
    print()
    print(titles)
# Out:
# 1
#
#
#
# [('Рука На Миллион\n2014', 'BAACAgIAAx0CXVwkEAACBmllYibc8kbAObSmIGpSRqc5ou21UgACpjwAAg-p8UovKLmE9O8S_R4E'), ('Светло Будущее\n1986', 'BAACAgIAAx0CXVwkEAACBmhlYibceG-yqwpbV4OGlot1a0ksdgACpTwAAg-p8UqBmdfEn8YAAbQeBA'), ('Человек С Планом\n2014', 'BAACAgIAAx0CXVwkEAACBmZlYibcTqH8xPIV2jM0xXUvb7Z58wACSDwAAg-p8UrlBxh-ZvnSlR4E'), ('Уитнэйл И Я\n1986', 'BAACAgIAAx0CXVwkEAACBmVlYibcxKjEy_LL9_o1aumBJZW1dAACRjwAAg-p8UoHPD4egxCozx4E'), ('Эпоха Радио\n1987', 'BAACAgIAAx0CXVwkEAACBmJlYibcjnQZuKA5DfcJm5WBvXFZ1AACyDsAAg-p8UqTnSMcVHoKcR4E'), ('Новый Мир\n2013', 'BAACAgIAAx0CXVwkEAACBmFlYibcCby6nvDuur7QC4KR3RaUVAACvzsAAg-p8UrQuHJwdnfyCx4E'), ('Воспитание Аризоны\n1987', 'BAACAgIAAx0CXVwkEAACBl1lYibct3Stx7tDcLwSZVJTaf_eyQACUjsAAg-p8Uo4zUZZ591ycx4E'), ('Великая Красота\n2013', 'BAACAgIAAx0CXVwkEAACBlxlYibcPsFwDIMIu9H5OJ7snUonQwACSDsAAg-p8UqQI_vZeYCKbh4E'), ('Держись За Меня\n1989', 'BAACAgIAAx0CXVwkEAACBlplYibcgJHeIUUlLniK
0CXVwkEAACBjZlYibcUpe0uPw62ktlJ9Niwww3KgACVTcAAnziuUp74-l4IVRd-h4E'), ('Коррина, Коррина\n1994', 'BAACAgIAAx0CXVwkEAACBjVlYibcysvkZt32sxlrSZCnZmlvygACMTcAAnziuUq0TzWwu4lJWx4E'), ('Лондон\n2006', 'BAACAgIAAx0CXVwkEAACBjNlYibckMauXGSSzePvpWN0mO_3OQACGzcAAnziuUo6mPUyE_jerR4E'), ('Адамовы Яблоки\n2005', 'BAACAgIAAx0CXVwkEAACBjJlYibcv5300LoKJ2d9XGNmOEpVVgACdjcAAiOrsEpht45JXqedeB4E'), ('Разум И Чувства\n1995', 'BAACAgIAAx0CXVwkEAACBjBlYibcIrbXryoeEfnr9sAbq3zokQACZTcAAiOrsEqsZOTcenduAh4E'), ('Ягуар\n1996', 'BAACAgIAAx0CXVwkEAACBi9lYibcLjm4RcvllbHp0OB3dq9cqAAC9DYAAiOrsErrhYtS-kIl6h4E'), ('Скрытый Клинок\n2004', 'BAACAgIAAx0CXVwkEAACBi1lYibcAcTeLzZ0tb8lWRTWReA-VgACKkEAAiOrqEpkBZ29gxyZih4E'), ('Мужество В Бою\n1996', 'BAACAgIAAx0CXVwkEAACBixlYibcHrrClTcRNXmCWiV2XH1VMwACFEEAAiOrqEo-KyTz9XfhRR4E'), ('Красота По-английски\n2004', 'BAACAgIAAx0CXVwkEAACBiplYibcKby0A615B2m-Fy74RsvyZAACxUAAAiOrqEovPtdfI6wp4R4E'), ('И В Бедности И В Богатстве\n1997', 'BAACAgIAAx0CXVwkEAACBillYibc-FI3BTQ5GrvHnWRzYMmg7AACAUAAAiOrqErYCLRhICu8jR4E'), ('Дом Из Песка И Тумана\n2003', 'BAACAgIAAx0CXVwkEAACBidlYibcSo9ThD_VTbkIjsA07yqirwACfj8AAiOrqEpk8juY-S4GHh4E'), ('Ловкие Руки\n2002', 'BAACAgIAAx0CXVwkEAACBiZlYibcCFZGpQ2LBm5-N3JwCfKeoQA ...

# %%
all_movies=[]
async with Client("my_account", api_id, api_hash) as app:
    async for message in app.get_chat_history(content_chat_id):
        if message.caption is not None:
            msg_list=message.caption.split('\n')
            if len(msg_list)==2:
                caption=msg_list[0]
                year=msg_list[1]
            else:
                year=None
                caption=msg_list[0]
    
            message_id=message.id
            
            br=(caption,year,message_id)
            all_movies.append(br)
        
        
print(all_movies)
# Out:
# [('Мэверик', '1994', 3143), ('Весёлые Каникулы', '2011', 3142), ('Апокалипсис', '2006', 3141), ('По Соображениям Совести', '2016', 3140), ('Смертельное Оружие 4', '1998', 3139), ('Грань Будущего', '2014', 3138), ('Невидимая Сторона', '2009', 3137), ('Ярость', '2014', 3136), ('Август Раш', '2007', 3135), ('Робин Гуд', '2010', 3134), ('Индиана Джонс И Последний Крестовый Поход', '1989', 3133), ('Индиана Джонс: В Поисках Утраченного Ковчега', '1981', 3132), ('Вспоминая Титанов', '2000', 3131), ('Терминатор 2: Судный День', '1991', 3130), ('Спеши Любить', '2002', 3129), ('Тренер Картер', '2005', 3128), ('Притворись Моей Женой', '2011', 3127), ('Мумия', '1
), ('Легенда №17', '2013', 3043), ('Человек, Который Изменил Все', '2011', 3042), ('Престиж', '2006', 3041), ('Отступники', '2006', 3040), ('Васаби', '2001', 3039), ('Брюс Всемогущий', '2003', 3038), ('За Бортом', '1987', 3037), ('Олдбой', '2003', 3036), ('Хищник', '1987', 3035), ('Выживший', '2015', 3034), ('Побег Из Шоушенка', '1994', 3033), ('Пятый Элемент', '1997', 3032), ('Терминал', '2004', 3031), ('Дом У Озера', '2006', 3030), ('Оскар', '1991', 3029), ('Последний Самурай', '2003', 3028), ('Бриллиантовая Рука', '1968', 3027), ('Достать Ножи ...

# %%
from src.db_controller import db
async def bebra():
    for i in all_movies:
        await db.add_movie(i[0],i[2],i[1])

        
await bebra()

# %%
print(content_titles)
# Out:
# ['Малефисента', 'Зеленый Фонарь: Изумрудные Рыцари', 'Зеленый Фонарь: Первый Полет', 'Шрек 1', 'Шрек 2', 'Шрек 3', 'Шрек 4', 'Доктор Стрендж И Тайна Ордена Магов', 'Супермен: Судный День', 'Лига Справедливости: Трон Атлантиды»', 'Тор: Сказания Асгарда»', 'Планета Сокровищ»', 'Ральф против интернета', 'Щелкунчик И Мышиный Король', 'Соляная Принцесса', 'Алые Паруса', 'Человек - Амфибия', 'Сказка О Потерянном Времени', 'Джентльмены Удачи', 'Иван Васильевич Меняет Профессию', 'Финист — Ясный Сокол', 'Фильм-сказка "синяя Птица"', 'Берегите Женщин', 'Мультфильм 2019 Красные Туфельки И Семь Гномов', 'Золушка И Тайный Принц Новинка!!! 2019', 'Барби | Рождественская История | 2008', 'Смурфики', 'Смурфики 2', 'Смурфики 3: Затерянная Деревня', 'Валли', 'Дети шпионов', 'Дети шпионов 2', 'Семейка Адамс', 'Алиса В Зазеркалье', 'Принцесса И Лягушка', 'Собачья жизнь', 'Собачья жизнь 2', 'Гарфилд 2', 'Ледяная Принцесса', 'Барби: Академия Принцесс', 'Спайдерчив Хроники', 'Чудо Детки', 'Большой Сборник Мультсериала "том И Джерри"', 'Мультик', 'Рыбка Поньо На Утёсе', 'Монстр Дом 2006', 'Дневник Принцессы:как Стать Королевой', 'Бэмби 2', 'Богатенький Ричи', 'Стань Легендой! Бигфут Младший', 'Валериан И Город Тысячи Планет', 'Облачно Возможны Осадки В Виде Фрикаделек', 'Семейка Крудс: Новоселье', 'Три Богатыря Ход Конём', 'По Ту Сторону Океана', 'Жил - Был Кот', 'Книга Мастеров', 'Бэтмен: Убийственная Шутка', 'Алеша Попович И Тугарин Змей', 'Клара И Волшебный Дракон', 'Дракон Желаний', 'Рая И Последний Дракон', 'Хатико', 'Хранитель Луны', 'Сельма В Городе Призраков', 'Семья Уиллоби', 'Пушистые Мошенники', 'Капитан Саблезуб И Волшебный Бриллиант', 'Девять', 'Плюшевый Монстр', 'Скуби-ду И Кибер Погоня - 2001', 'Скуби-ду И Проклятье Тринадцатого Призрака', 'Скуби-ду:"где Моя Мумочка?"', 'Эспен В Королевстве Троллей', 'Норм И Несокрушимые', 'Лесси Возвращение Домой', 'Гнездо Дракона - 2015', 'Дальняя Дорога- 2015', 'Повелитель Драконов', 'Карлик Нос', 'Земля До Начала Времён - 1988', 'Джек И Механическое Сердце - 2013', 'Лето. Пляж 1', 'Лето. Пляж 2', 'Творцы Снов', 'Зубная Фея', 'Барашек Шон Фермагеддон', 'Фердинанд', 'Феи Тайна Страны Драконов', 'Барби И Щенки - 2015', 'Несокрушимые Мстители - 2006', 'Руслан И Людмила: Перезагрузка', 'Твоё Имя', 'Ведьмина Служба Доставки', 'Укрась Прощальное Утро Цветами Обещания', 'Форма Голоса', 'Хортон', 'Шерлок Гномс', 'Рок Дог', 'Скуби-ду И Kiss: Тайна Рок-н-ролла', 'Упс… Ной Уплыл!', 'Астробой', 'Айнбо. Сердце Амазонии', 'Скуби-ду При Дворе Короля Артура', 'Хороший Динозавр', 'Кунг-фу Панда', 'Кунг-фу Панда 2', 'Кунг-фу Панда 3', 'Совсем Другая Магия', 'Волшебный Мир Бель', 'Облачно, Возможны Осадки В Виде Фрикаделек 2: Месть Гмо', 'Дамбо', 'Дорога На Эльдорадо', 'Савва. Сердце Воина', 'Принцесса Эмми', 'Гуррен Лагган', 'Приключения Паддингтона', 'Астрал 1', 'Горбун Из Нотер Дама', 'Барлок Великолепный', 'Тайна Четырёх Принцесс', 'Водяная', 'Всем Парням, Которых Я Любила', 'Не Все Дома', 'Виво', 'Семейка Бигфутов', 'Академия Монстров', 'Куриный Забег', 'Упс! Приплыли...', 'Механика Сердце', 'Губка Боб В 3d', 'Бapби: Дpимтoпия. Фecтивaль Вeсeлья', 'Barbie: Бaлeринa В Poзoвыx Пyaнтaх', 'Её Заветное Желание', 'Книга Жизни - 2014', 'Бoгиня Блaгocлoвляeт Этoт Пpeкpacный Миp: Бaгpoвaя Лeгeндa', 'Красный Свиток', 'Она Видела Небо', '5 Сантиметров В Секунду', 'Мультфильм Песнь Моря', 'Мультфильм - Богатырша', 'Кволик 1-6 Серии', 'Кволик', 'Бэтмен Против Черепашек-ниндзя', 'Eщё Вчepa', 'Kpoлик Питep', 'Kpoлuк Пuтep 2', 'Любит Не Любит', 'Oбитeль Злa: Вырoждeниe', 'Пpиключeния Миcтepa Пибoди И Шepмaнa', 'Пyтeшecтвие Нa Зaпaд', 'Сердце Хочет Кричать', 'Унесённые Призраками', 'Фиксики Против Кработов', 'Я Пoтepялa Cвoё Тeлo', 'Мой Дедушка Инопланетянин', 'Полет Навигатора', 'Осторожно, Каникулы.', 'Camp Rock Музыкальные Каникулы', 'Возврат В Рождество', 'Наследники 1', 'Наследники 2', 'Наследники 3', 'Мультфильм: Миньоны', 'Мультфильм: Рапунцель', 'Название Фильма: Гарфилд', 'Человек Паук: Высокое Напряжение', 'Снежная Кор ...

# %%
titles=dict(titles)

# %%
print(len(titles.keys()))
# Out:
# 1152

# %%
from time import sleep
from random import randint
async with Client("my_account", api_id, api_hash) as app:
    for i in titles.items():
        await app.send_video(content_chat_id,video=i[1],caption=i[0])
        sleep(0.1*randint(0,5))

# %%
async with Client("my_account", api_id, api_hash) as app:
    #print(await app.get_chat(target_chat_id2))
    msgs_cnt=await app.get_chat_history_count(content_chat_id)
    print(msgs_cnt)
# Out:
# 2792
