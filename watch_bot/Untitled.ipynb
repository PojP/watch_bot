# %%
#from src.db_controller import db
import pyrogram
from config_reader import config
import asyncio
import re
from pyrogram import Client

api_id = int(config.api_id.get_secret_value())
api_hash = config.api_hash.get_secret_value()
content_chat_id=int(config.chat_id.get_secret_value())
target_chat_id=-1001902274622
target_chat_id2=-1001566319632

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def capital(s:str) -> str:
    return s.capitalize()

# %%
print(1)
async with Client("my_account", api_id, api_hash) as app:
    #print(await app.get_chat(target_chat_id2))
    msgs_cnt=await app.get_chat_history_count(target_chat_id2)
    #print(msgs_cnt)
    counter=0
    titles=[]
    alph="йцукенгшщзхъфывапролджэячсмитьбюqwertyuiopasdfghjklzxcvbnm"
    alph+=alph.upper()+"0123456789"
    
    async for message in app.get_chat_history(target_chat_id2):
        if message.caption is not None and message.video is not None and message.video.duration>600:
            #print(message.caption)
            s=message.caption.split('\n')
            s=( " ".join(list(map(capital, (s[0].split('.')[1].split(' (')[0]).split() )))   +"\n"+s[1])
            #print(s)
            
            br=(s,message.video.file_id)
            titles.append(br)
            
            """if s[0] not in alph:
                s=s[1:]
            s=s.split("#")[0]
            s= ' '.join(s.split())
            s=remove_emoji(s)
            bad_array=["https://t.me/gairithi/83"]
            if s not in titles and not s.split(" «")[0].isdigit():
                if not any(ext in s for ext in bad_array):
                    s=s.split('/')[0]
                    s=
                    s=s.replace("Hd 1080p","").replace("Sd",'').replace("Hd",'').replace('720p','').replace('_'," ")
                    br=(s,message.video.file_id)
                    titles.append(br)
                    print(br)
                    counter+=1
            
    print(counter)"""
    print()
    print()
    print()
    print(titles)
# Out:
# 1
#
#
#
# ...

# %%
all_movies=[]
async with Client("my_account", api_id, api_hash) as app:
    async for message in app.get_chat_history(content_chat_id):
        if message.caption is not None:
            msg_list=message.caption.split('\n')
            if len(msg_list)==2:
                caption=msg_list[0]
                year=msg_list[1]
            else:
                year=None
                caption=msg_list[0]
    
            message_id=message.id
            
            br=(caption,year,message_id)
            all_movies.append(br)
        
        
print(all_movies)
# Out:
# [('Оппенгеймер', '2023', 3150), ('Американский психопат', '2000', 3149), ('Лолита', '1997', 3148), ('Мэверик', '1994', 3143), ('Весёлые Каникулы', '2011', 3142), ('Апокалипсис', '2006', 3141), ('По Соображениям Совести', '2016', 3140), ('Смертельное Оружие 4', '1998', 3139), ('Грань Будущего', '2014', 3138), ('Невидимая Сторона', '2009', 3137), ('Ярость', '2014', 3136), ('Август Раш', '2007', 3135), ('Робин Гуд', '2010', 3134), ('Индиана Джонс И Последний Крестовый Поход', '1989', 3133), ('Индиана Джонс: В Поисках Утраченного Ковчега', '1981', 3132), ('Вспоминая Титанов', '2000', 3131), ('Терминатор 2: Судный День', '1991', 3130), ('Спеши Любить', '2002', 3129), ('Тренер Картер', '2005', 3128), ('Притворись Моей Женой', '2011', 3127), ('Мумия', '1999', 3126), ('Мумия Возвращается', '2001', 3125), ('Принц Персии: Пески Времени', '2010', 3124), ('Карты, Деньги, Два Ствола', '1998', 3123), ('Сокровище Наций', '2004', 3122), ('Сокровище Амазонки', '2003', 3121), ('Угнать За 60 Секунд', '
# ...

# %%
ed_movies=[]


    
for i in all_movies:
    if i[1] is not None:
        ed_movies.append(i)

# %%
print(ed_movies)
# Out:
# [('Оппенгеймер', '2023', 3150), ('Американский психопат', '2000', 3149), ('Лолита', '1997', 3148), ('Мэверик', '1994', 3143), ('Весёлые Каникулы', '2011', 3142), ('Апокалипсис', '2006', 3141), ('По Соображениям Совести', '2016', 3140), ('Смертельное Оружие 4', '1998', 3139), ('Грань Будущего', '2014', 3138), ('Невидимая Сторона', '2009', 3137), ('Ярость', '2014', 3136), ('Август Раш', '2007', 3135), ('Робин Гуд', '2010', 3134), ('Индиана Джонс И Последний Крестовый Поход', '1989', 3133), ('Индиана Джонс: В Поисках Утраченного Ковчега', '1981', 3132), ('Вспоминая Титанов', '2000', 3131), ('Терминатор 2: Судный День', '1991', 3130), ('Спеши Любить', '2002', 3129), ('Тренер Картер', '2005', 3128), ('Притворись Моей Женой', '2011', 3127), ('Мумия', '1999', 3126), ('Мумия Возвращается', '2001', 3125), ('Принц Персии: Пески Времени', '2010', 3124), ('Карты, Деньги, Два Ствола', '1998', 3123), ('Сокровище Наций', '2004', 3122), ('Сокровище Амазонки', '2003', 3121), ('Угнать За 60 Секунд', '
# ...

# %%
def remove_all_symbols(s:str):
    return s.replace('.','').replace(',','').replace(':','').lower()
def remove_all_symbols_tuple(s):
    return s[0].replace('.','').replace(',','').replace(':','').lower()

# %%
n_list=[]
for i in ed_movies:
    if remove_all_symbols(i[0]) not in list(map(remove_all_symbols_tuple,n_list)):
        n_list.append(i)
        
print(len(n_list))
print(len(ed_movies))
# Out:
# 1143
# 1154

# %%
not_ed_movies=[]
for i in all_movies:
    if i[1] is None:
        not_ed_movies.append(i)

# %%
for i in not_ed_movies:
    if remove_all_symbols(i[0]) not in list(map(remove_all_symbols_tuple,n_list)):
        n_list.append(i)

# %%
print(len(n_list))
# Out:
# 2601

# %%
def check(x):
    if "Оппенгеймер" in x[0]:
        return True

# %%
for i in n_list:
    if check(i):
        print(i)
# Out:
# ('Оппенгеймер', '2023', 3150)

# %%
print(n_list)
# Out:
# [('Оппенгеймер', '2023', 3150), ('Американский психопат', '2000', 3149), ('Лолита', '1997', 3148), ('Мэверик', '1994', 3143), ('Весёлые Каникулы', '2011', 3142), ('Апокалипсис', '2006', 3141), ('По Соображениям Совести', '2016', 3140), ('Смертельное Оружие 4', '1998', 3139), ('Грань Будущего', '2014', 3138), ('Невидимая Сторона', '2009', 3137), ('Ярость', '2014', 3136), ('Август Раш', '2007', 3135), ('Робин Гуд', '2010', 3134), ('Индиана Джонс И Последний Крестовый Поход', '1989', 3133), ('Индиана Джонс: В Поисках Утраченного Ковчега', '1981', 3132), ('Вспоминая Титанов', '2000', 3131), ('Терминатор 2: Судный День', '1991', 3130), ('Спеши Любить', '2002', 3129), ('Тренер Картер', '2005', 3128), ('Притворись Моей Женой', '2011', 3127), ('Мумия', '1999', 3126), ('Мумия Возвращается', '2001', 3125), ('Принц Персии: Пески Времени', '2010', 3124), ('Карты, Деньги, Два Ствола', '1998', 3123), ('Сокровище Наций', '2004', 3122), ('Сокровище Амазонки', '2003', 3121), ('Угнать За 60 Секунд', '
# ...

# %%
from src.db_controller import db as dbb
await dbb.init()
print(len(n_list))
async def bebra():
    for i in n_list:
        print(i)
        if i[1] is not None:
            if i[1].isdigit():
                a=await dbb.add_movie(i[0],i[2],int(i[1]))
            else:
                a=await dbb.add_movie(i[0],i[2],None)
        else:
            a=await dbb.add_movie(i[0],i[2],None)
        print(a)
        
await bebra()
# Out:
# bot4movie
# all added
# 2601
# ('Оппенгеймер', '2023', 3150)
# True
# ('Американский психопат', '2000', 3149)
# True
# ('Лолита', '1997', 3148)
# True
# ('Мэверик', '1994', 3143)
# True
# ('Весёлые Каникулы', '2011', 3142)
# True
# ('Апокалипсис', '2006', 3141)
# True
# ('По Соображениям Совести', '2016', 3140)
# True
# ('Смертельное Оружие 4', '1998', 3139)
# True
# ('Грань Будущего', '2014', 3138)
# True
# ('Невидимая Сторона', '2009', 3137)
# True
# ('Ярость', '2014', 3136)
# True
# ('Август Раш', '2007', 3135)
# True
# ('Робин Гуд', '2010', 3134)
# True
# ('Индиана Джонс И Последний Крестовый Поход', '1989', 3133)
# True
# ('Индиана Джонс: В Поисках Утраченного Ковчега', '1981', 3132)
# True
# ('Вспоминая Титанов', '2000', 3131)
# True
# ('Терминатор 2: Судный День', '1991', 3130)
# True
# ('Спеши Любить', '2002', 3129)
# True
# ('Тренер Картер', '2005', 3128)
# True
# ('Притворись Моей Женой', '2011', 3127)
# True
# ('Мумия', '1999', 3126)
# True
# ...

# %%
print(content_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(content_titles)
#
# NameError: name 'content_titles' is not defined

# %%
titles=dict(titles)

# %%
print(len(titles.keys()))

# %%
from time import sleep
from random import randint
async with Client("my_account", api_id, api_hash) as app:
    for i in titles.items():
        await app.send_video(content_chat_id,video=i[1],caption=i[0])
        sleep(0.1*randint(0,5))

# %%
async with Client("my_account", api_id, api_hash) as app:
    #print(await app.get_chat(target_chat_id2))
    msgs_cnt=await app.get_chat_history_count(content_chat_id)
    print(msgs_cnt)
